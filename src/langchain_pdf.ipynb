# %% [markdown]
# # Install Libraries

# %%
# !pip install langchain --quiet
# !pip install pdfminer.six
# !pip install pillow-heif
# !pip install opencv-python-headless
# !pip install pikepdf unstructured_inference pytesseract
# !pip install -U langchain-openai
# !pip install openai --quiet
# !pip install pdf2image --quiet
# !pip install tiktoken --quiet
# !pip install unstructured --quiet
# !pip install python-dotenv
# Out:
# Requirement already satisfied: pdfminer.six in /opt/conda/lib/python3.11/site-packages (20231228)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from pdfminer.six) (3.3.0)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/conda/lib/python3.11/site-packages (from pdfminer.six) (41.0.4)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Requirement already satisfied: pillow-heif in /opt/conda/lib/python3.11/site-packages (0.16.0)
# Requirement already satisfied: pillow>=9.5.0 in /opt/conda/lib/python3.11/site-packages (from pillow-heif) (10.3.0)
# Requirement already satisfied: opencv-python-headless in /opt/conda/lib/python3.11/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.11/site-packages (from opencv-python-headless) (1.26.2)
# Requirement already satisfied: pikepdf in /opt/conda/lib/python3.11/site-packages (8.15.1)
# Requirement already satisfied: unstructured_inference in /opt/conda/lib/python3.11/site-packages (0.7.29)
# Requirement already satisfied: pytesseract in /opt/conda/lib/python3.11/site-packages (0.3.10)
# Requirement already satisfied: Pillow>=10.0.1 in /opt/conda/lib/python3.11/site-packages (from pikepdf) (10.3.0)
# Requirement already satisfied: Deprecated in /opt/conda/lib/python3.11/site-packages (from pikepdf) (1.2.14)
# Requirement already satisfied: lxml>=4.8 in /opt/conda/lib/python3.11/site-packages (from pikepdf) (5.2.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from pikepdf) (23.2)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (0.3.4)
# Requirement already satisfied: python-multipart in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (0.0.9)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (0.22.2)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (4.9.0.80)
# Requirement already satisfied: onnx in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (1.16.0)
# Requirement already satisfied: onnxruntime>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (1.17.3)
# Requirement already satisfied: transformers>=4.25.1 in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (4.40.1)
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.11/site-packages (from unstructured_inference) (3.8.1)
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.3.25)
# Requirement already satisfied: numpy>=1.24.2 in /opt/conda/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (1.26.2)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (5.26.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from onnxruntime>=1.17.0->unstructured_inference) (1.12)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (2023.12.25)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.11/site-packages (from transformers>=4.25.1->unstructured_inference) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub->unstructured_inference) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub->unstructured_inference) (4.8.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.11/site-packages (from Deprecated->pikepdf) (1.16.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (1.13.0)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.0.3)
# Requirement already satisfied: iopath in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (0.1.10)
# Requirement already satisfied: pdfplumber in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (0.11.0)
# Requirement already satisfied: pdf2image in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (1.17.0)
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.3.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (0.18.0)
# Requirement already satisfied: effdet in /opt/conda/lib/python3.11/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured_inference) (0.4.1)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured_inference) (10.0)
# Requirement already satisfied: timm>=0.9.2 in /opt/conda/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (0.9.16)
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/conda/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /opt/conda/lib/python3.11/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.3.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /opt/conda/lib/python3.11/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (12.4.127)
# Requirement already satisfied: portalocker in /opt/conda/lib/python3.11/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2023.4)
# Requirement already satisfied: pdfminer.six==20231228 in /opt/conda/lib/python3.11/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured_inference) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/conda/lib/python3.11/site-packages (from pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured_inference) (4.29.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured_inference) (3.3.0)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/conda/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured_inference) (41.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers>=4.25.1->unstructured_inference) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers>=4.25.1->unstructured_inference) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers>=4.25.1->unstructured_inference) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->onnxruntime>=1.17.0->unstructured_inference) (1.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.11/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (3.8.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->layoutparser[layoutmodels,tesseract]->unstructured_inference) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.1.3)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured_inference) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured_inference) (3.1.2)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser[layoutmodels,tesseract]->unstructured_inference) (2.21)
# Requirement already satisfied: langchain-openai in /opt/conda/lib/python3.11/site-packages (0.1.4)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.46 in /opt/conda/lib/python3.11/site-packages (from langchain-openai) (0.1.46)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in /opt/conda/lib/python3.11/site-packages (from langchain-openai) (1.23.6)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in /opt/conda/lib/python3.11/site-packages (from langchain-openai) (0.6.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.46->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.46->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.46->langchain-openai) (0.1.51)
# Requirement already satisfied: packaging<24.0,>=23.2 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.46->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.46->langchain-openai) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.46->langchain-openai) (8.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (0.27.0)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/conda/lib/python3.11/site-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.8.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.11/site-packages (from tiktoken<1,>=0.5.2->langchain-openai) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /opt/conda/lib/python3.11/site-packages (from tiktoken<1,>=0.5.2->langchain-openai) (2.31.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.10.0->langchain-openai) (3.4)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.46->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langchain-openai) (3.10.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.46->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /opt/conda/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.46->langchain-openai) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.5.2->langchain-openai) (3.3.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.5.2->langchain-openai) (2.2.1)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (1.0.1)

# %%
from langchain.document_loaders import OnlinePDFLoader

#if using on your S2 workspace remember to add a firewall exception for https://contentserver.adobe.com
loader = OnlinePDFLoader("https://www.sjsu.edu/writingcenter/docs/handouts/Research%20Papers%20in%20the%20Sciences.pdf")

data = loader.load()
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Param.DESKTOP-MEMSLIO/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Check to see how many documents and chars in the pdf

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

print(f"You have {len(data)} document(s) in your data")
print(f"There are {len(data[0].page_content)} characters in your document")
# Out:
# Running cells with 'Python 3.9.13 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Param.DESKTOP-MEMSLIO/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Now let's split the data into chunks before we turn them into embeddings

# %%
# Split the data
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 2000, chunk_overlap = 0)
texts = text_splitter.split_documents(data)

# Check how many documents do we have now
print(f"You have {len(texts)} pages")

# %% [markdown]
# # Let's convert these chunks into embeddings and then store it in a SingleStore table

# %% [markdown]
# ## Let's create the table first

# %%
# %%sql
# USE reader_data;
# DROP TABLE IF EXISTS my_book;
# CREATE TABLE IF NOT EXISTS my_book (
#     id INT PRIMARY KEY,
#     text TEXT CHARACTER SET utf8mb4 COLLATE utf8mb4_general_ci,
#     embedding BLOB
# );

# %% [markdown]
# ## Connect to OpenAI API

# %%
import openai
import os
from dotenv import load_dotenv

# Load variables from .env file
load_dotenv('.env')

# Check to see if there is an environment variable with your API Key,
# If not, use what you put below.

OPENAI_API_KEY = os.environ.get('OPENAI_API_KEY')

# %%
print(texts[0].__dict__)

# %%
from sqlalchemy import *

db_connection = create_engine(connection_url)
sql_connection = db_connection.connect()

# %%
from langchain_openai import OpenAIEmbeddings

# Initialize the OpenAIEmbeddings
embedder = OpenAIEmbeddings(openai_api_key = OPENAI_API_KEY)

# %% [markdown]
# # Now let's add the embeddings to the my_book table. Truncate to make sure we don't overwrite.

# %%
from sqlalchemy import text

# Clear the my_book table
sql_connection.execute(text("TRUNCATE TABLE my_book;"))

# Iterate over the texts
for i, document in enumerate(texts):
    # Extract the text content from the Documents
    text_content = document.page_content

    # Convert the text to embeddings
    embedding = embedder.embed_documents([text_content])[0]
    print(f"Embedding {i}: {embedding}\n")

    # Insert the text and its embedding into the database
    stmt = """
        INSERT INTO my_book (
            id,
            text,
            embedding
        )
        VALUES (
            :id,
            :text,
            JSON_ARRAY_PACK_F32(:embedding)
        )
    """
    parameters = {
        'id': int(i),
        'text': str(text_content),
        'embedding': str(embedding)
    }

    sql_connection.execute(text(stmt), parameters)

sql_connection.close()

# %%
# %%sql
# USE reader_data;
# SELECT JSON_ARRAY_UNPACK_F32(embedding), text
# FROM my_book
# WHERE id = 5;
